# %% [markdown]
# # Load Data:

# %%
import pandas as pd
data = pd.read_csv('heart_disease.csv')

# %% [markdown]
# # ElasticNet: predict cholesterol level

# %%
import os
import pandas as pd
from regression import train_elasticnet_grid

# Predict the serum cholesterol using ElasticNet:
pred_chol = train_elasticnet_grid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 from regression import train_elasticnet_grid
#       3 # # Predict the serum cholesterol using ElasticNet:
# ----> 4 pred_chol = train_elasticnet_grid()
#
# TypeError: train_elasticnet_grid() missing 4 required positional arguments: 'X_train', 'y_train', 'l1_ratios', and 'alphas'
